# %%
import thinkdsp as td
import numpy as np

class YRTrombone(td.Chirp):
    
    def evaluate(self, ts):

        l1, l2=  1.0/self.start, 1.0/self.end
        lengths= np.linspace(l1, l2, len(ts)-1)
        freqs=   1/lengths
        return self._evaluate(ts, freqs)

# %%
A3=  220 
A4=  440

s1= YRTrombone(start= A3, end= A4)
w1= s1.make_wave(duration=1)
w1.make_spectrogram(512).plot(high=1000)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-135-ef74613c4b3b> in <module>
#       3
#       4 s1= YRTrombone(start= A3, end= A4)
# ----> 5 w1= s1.make_wave(duration=1)
#       6 w1.make_spectrogram(512).plot(high=1000)
#
# ~\thinkdsp.py in make_wave(self, duration, start, framerate)
#    1238         n = round(duration * framerate)
#    1239         ts = start + np.arange(n) / framerate
# -> 1240         ys = self.evaluate(ts)
#    1241         return Wave(ys, ts, framerate=framerate)
#    1242
#
# <ipython-input-134-be25a1c0d03c> in evaluate(self, ts)
#       9         lengths= np.linspace(l1, l2, len(ts)-1)
#      10         freqs=   1/lengths
# ---> 11         return self._evaluate(ts, freqs)
#
# AttributeError: 'YRTrombone' object has no attribute '_evaluate'
